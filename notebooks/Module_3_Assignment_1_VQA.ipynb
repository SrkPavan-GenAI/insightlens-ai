# %%
# !pip install -q langchain-google-genai pillow python-dotenv
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.1/53.1 kB 2.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.5/66.5 kB 2.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 719.4/719.4 kB 13.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 236.5/236.5 kB 7.9 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires google-auth==2.43.0, but you have google-auth 2.48.0 which is incompatible.

# %%
# !pip install -q python-dotenv

# %%
from dotenv import load_dotenv
import os

load_dotenv()

print("API Loaded:", os.getenv("GOOGLE_API_KEY")[:10] + "********")
# Out:
# API Loaded: AIzaSyCxtu********

# %%
from PIL import Image
from langchain_google_genai import ChatGoogleGenerativeAI
from langchain_core.messages import HumanMessage
from IPython.display import display

llm = ChatGoogleGenerativeAI(
    model="gemini-3-flash-preview",
    temperature=0.3
)

print("🖼️ Upload an image and ask a question!")
# Out:
# 🖼️ Upload an image and ask a question!

# %%
from google.colab import files
uploaded = files.upload()

image_path = list(uploaded.keys())[0]
img = Image.open(image_path)
display(img)
# Out:
#      <input type="file" id="files-a78da435-1d9c-4b2b-861a-bfd13ca03b58" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-a78da435-1d9c-4b2b-861a-bfd13ca03b58">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# !pip install -q langchain-google-genai pillow python-dotenv

# %%
from google.colab import userdata

api_key = userdata.get("Gemini")
print("Key loaded:", api_key[:5], "*****")
# Out:
# Key loaded: AIzaS *****

# %%
import google.generativeai as genai

genai.configure(api_key=api_key)

model = genai.GenerativeModel("gemini-3-flash-preview")
# Out:
# /usr/local/lib/python3.12/dist-packages/google/colab/_import_hooks/_hook_injector.py:55: FutureWarning:
#
# All support for the `google.generativeai` package has ended. It will no longer be receiving
# updates or bug fixes. Please switch to the `google.genai` package as soon as possible.
# See README for more details:
#
# https://github.com/google-gemini/deprecated-generative-ai-python/blob/main/README.md
#
#   loader.exec_module(module)

# %%
from google.colab import files
from PIL import Image
import io

uploaded = files.upload()
image_path = list(uploaded.keys())[0]

img = Image.open(image_path)
display(img)
# Out:
#      <input type="file" id="files-7ba398d2-d297-4d32-bd30-2105f07e674b" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-7ba398d2-d297-4d32-bd30-2105f07e674b">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
question = input("Ask a question about the image: ")

response = model.generate_content([question, img])

print("\n🤖 Gemini Answer:\n", response.text)
# Out:
# Ask a question about the image: what is Agentic AI?
#
# 🤖 Gemini Answer:
#  Based on the infographic provided and the current landscape of artificial intelligence, **Agentic AI** refers to AI systems designed to act as "agents" that can autonomously pursue complex goals.
#
# Unlike traditional AI or simple chatbots that just respond to prompts, Agentic AI doesn't just talk—it **acts.**
#
# Here is a breakdown of what makes AI "agentic," based on the key pillars shown in your image:
#
# ### 1. Goal-Oriented Autonomy
# Standard AI follows a direct instruction (e.g., "Write an email"). Agentic AI is given a high-level goal (e.g., "Organize a three-day business trip to Tokyo within a $2,000 budget"). It then determines the necessary steps, makes decisions, and executes them without needing constant human intervention.
#
# ### 2. Key Capabilities (The "Petals" in your image)
# The diagram highlights several specific functions that turn a model into an agent:
# ...
